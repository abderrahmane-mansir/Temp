# %% [markdown]
# <center><h1><b>DataSet Cleaner</b></h1></center>

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
# Set random seeds for reproducibility
seed = 42
np.random.seed(seed)
import random
random.seed(seed)

# %% [markdown]
# **Load the Training Dataset**

# %%
train = pd.read_csv('..\DataSet\ViralPredict_Train.csv')
train.head(2)
# Out:
#      Post_ID                                     Pseudo_Caption   Post_Date  \
# 0   Post_574       youtube Video about #Gaming posted in Canada  2022-10-10
# 1  Post_2708  tiktok Live Stream about #Education posted in ...  2023-11-07
#
#   Platform     Hashtag Content_Type      Region      Views     Likes   Shares  \
# 0  YOUTUBE     #Gaming        Video    Canada    3620989.0  185166.0  73884.0
# 1   Tiktok  #Education  Live Stream       INDIA  1876306.0  149927.0  65747.0
#
#   Comments  Viral
# 0  46247.0      0
# 1  27923.0      1

# %% [markdown]
# **Dataset Overview**
#
# The dataset contains 4,500 rows and 11 columns including Post_ID, Pseudo_Caption, Post_Date, Platform, Hashtag, Content_Type, Region, and engagement metrics (Views, Likes, Shares, Comments) plus the target variable (Viral).

# %% [markdown]
# **Platform Distribution**

# %%
print("Dataset shape:", train.shape)
print(list(train.columns))
# Out:
# Dataset shape: (4500, 12)
# ['Post_ID', 'Pseudo_Caption', 'Post_Date', 'Platform', 'Hashtag', 'Content_Type', 'Region', 'Views', 'Likes', 'Shares', 'Comments', 'Viral']

# %%
train['Platform'].value_counts()
# Out:
# Platform
#   youtube        313
#   tiktok         308
# TWITTER          307
# Youtube          293
# instagram        289
# YOUTUBE          289
# tiktok           288
#   twitter        288
# youtube          285
# INSTAGRAM        284
# TIKTOK           271
# Tiktok           265
# Instagram        261
#   instagram      260
# twitter          258
# Twitter          241
# Name: count, dtype: int64

# %% [markdown]
# **Hashtag Distribution**

# %%
print(train['Hashtag'].value_counts())
# Out:
# Hashtag
# #Fitness      463
# #Education    458
# #Challenge    436
# #Comedy       434
# #Fashion      419
# #Dance        419
# #Music        418
# #Tech         417
# #Viral        406
# #Gaming       405
# #unknown       62
# #none          59
# #misc          56
# #error         48
# Name: count, dtype: int64

# %% [markdown]
# **Content Type Distribution**

# %%
print(train['Content_Type'].value_counts())
# Out:
# Content_Type
# Live Stream    771
# Post           769
# Video          747
# Reel           746
# Tweet          745
# Shorts         722
# Name: count, dtype: int64

# %% [markdown]
# **Region Distribution**

# %%
print(train['Region'].value_counts())
# Out:
# Region
#   Brazil         163
# usa              157
# USA              156
# uk               156
#   Canada         155
# CANADA           152
# Canada           152
# BRAZIL           151
# Australia        150
#   USA            149
# india            149
# Usa              148
# INDIA            145
# Japan            142
#   UK             142
# brazil           140
# Uk               140
# India            139
# japan            138
#   Australia      138
# UK               136
# Brazil           136
# canada           134
# AUSTRALIA        134
# germany          130
#   Germany        128
#   Japan          127
#   India          126
# australia        124
# GERMANY          122
# JAPAN            121
# Germany          120
# Name: count, dtype: int64

# %% [markdown]
# **Define Cleaning Function**
#
# Creating a helper function to standardize text columns by trimming whitespace and converting to lowercase.

# %%
def clean_column(column):
	train[column] = train[column].str.strip().str.lower()

# %% [markdown]
# **Standardize Column Names**
#
# Cleaning the Text columns to ensure consistent naming (all lowercase, no extra spaces). This groups variations like "YOUTUBE", "youtube", " youtube " into a single category.

# %%
clean_column('Platform')
clean_column('Content_Type')
clean_column('Hashtag')
clean_column('Region')

# %% [markdown]
# **Platform Distribution After Cleaning**

# %%
print(train['Platform'].value_counts())
# Out:
# Platform
# youtube      1180
# tiktok       1132
# twitter      1094
# instagram    1094
# Name: count, dtype: int64

# %% [markdown]
# **Hashtag Distribution After Cleaning**

# %%
print(train['Hashtag'].value_counts())
# Out:
# Hashtag
# #fitness      463
# #education    458
# #challenge    436
# #comedy       434
# #fashion      419
# #dance        419
# #music        418
# #tech         417
# #viral        406
# #gaming       405
# #unknown       62
# #none          59
# #misc          56
# #error         48
# Name: count, dtype: int64

# %% [markdown]
# **Content Type Distribution After Cleaning**

# %%
print(train['Content_Type'].value_counts())
# Out:
# Content_Type
# live stream    771
# post           769
# video          747
# reel           746
# tweet          745
# shorts         722
# Name: count, dtype: int64

# %% [markdown]
# **Region Distribution**

# %%
print(train['Region'].value_counts())
# Out:
# Region
# usa          610
# canada       593
# brazil       590
# uk           574
# india        559
# australia    546
# japan        528
# germany      500
# Name: count, dtype: int64

# %% [markdown]
# **Check for Duplicate Records**

# %%
duplicates = train.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# **Handle Dates**
#
# Date Column has some invalid entries `invalid_date` that need to be addressed.

# %%
invalid_date = train['Post_Date'] == 'invalid_date'
print(f"Invalid dates found: {invalid_date.sum()}")
# Out:
# Invalid dates found: 135

# %% [markdown]
# **Finding:** All rows with invalid dates also have missing engagement data (Views, Likes, Shares, Comments), making them unsuitable for analysis.

# %%
train[invalid_date].isnull().sum()
# Out:
# Post_ID             0
# Pseudo_Caption      0
# Post_Date           0
# Platform            0
# Hashtag             0
# Content_Type        0
# Region              0
# Views             135
# Likes             135
# Shares            135
# Comments          135
# Viral               0
# dtype: int64

# %% [markdown]
# **Dropping Rows with Invalid Dates**

# %%
train = train[~invalid_date]

# %% [markdown]
# **Pseudo_Caption Inspection**

# %% [markdown]
# Extracting unique values from the Pseudo_Caption column to identify patterns and inconsistencies.

# %%
# Lowercase and strip whitespace
clean_column('Pseudo_Caption')

# Extract features from Pseudo_Caption
train['parsed_platform'] = train['Pseudo_Caption'].str.split().str[0]
train['parsed_content_type'] = train['Pseudo_Caption'].str.extract(r'^\w+\s+(.+?)\s+about')[0]
train['parsed_hashtag'] = train['Pseudo_Caption'].str.extract(r'(#\w+)')[0]
train['parsed_region'] = train['Pseudo_Caption'].str.extract(r'posted in (.+)$')[0]

# Compare with existing columns
train[['parsed_platform', 'Platform']].head(2)
# Out:
#   parsed_platform Platform
# 0         youtube  youtube
# 1          tiktok   tiktok

# %%
# Compare with existing columns
match_rates = {
    'Platform': (train['Platform'] == train['parsed_platform']).mean() * 100,
    'Content_Type': (train['Content_Type'] == train['parsed_content_type']).mean() * 100,
    'Region': (train['Region'] == train['parsed_region']).mean() * 100,
    'Hashtag': (train['Hashtag'] == train['parsed_hashtag']).mean() * 100
}

print("Match rates against structured caption extracts:")
for label, rate in match_rates.items():
    matching = int(rate * len(train) / 100)
    print(f"  {label}: {matching} / {len(train)} ({rate:.2f}%)")
# Out:
# Match rates against structured caption extracts:
#   Platform: 4365 / 4365 (100.00%)
#   Content_Type: 4365 / 4365 (100.00%)
#   Region: 4365 / 4365 (100.00%)
#   Hashtag: 4274 / 4365 (97.94%)

# %% [markdown]
# **Hashtag Invalid Values**

# %% [markdown]
# The `Hashtag` column contains invalid entries such as `#misc`,`#error`, `#unknown`, `#none`

# %%
hashtag = train['Hashtag'].unique()
print(hashtag)
# Out:
# ['#gaming' '#education' '#fashion' '#comedy' '#tech' '#fitness' '#dance'
#  '#challenge' '#viral' '#music' '#misc' '#error' '#unknown' '#none']

# %% [markdown]
# **Filling Hashtag From Pseudo_Caption**

# %%
train["Hashtag"] = train["parsed_hashtag"]

# %% [markdown]
# **Dropping Additional Parsed Columns**

# %%
train = train.drop(columns=['Pseudo_Caption','parsed_platform', 'parsed_content_type', 'parsed_hashtag', 'parsed_region'])
train.head(2)
# Out:
#      Post_ID   Post_Date Platform     Hashtag Content_Type  Region      Views  \
# 0   Post_574  2022-10-10  youtube     #gaming        video  canada  3620989.0
# 1  Post_2708  2023-11-07   tiktok  #education  live stream   india  1876306.0
#
#       Likes   Shares Comments  Viral
# 0  185166.0  73884.0  46247.0      0
# 1  149927.0  65747.0  27923.0      1

# %% [markdown]
# **Handle Numerical Engagement Columns**

# %% [markdown]
# **Clean Engagement Metrics**
#
# The engagement columns (Views, Likes, Shares, Comments) contain numeric values with text suffixes that need to be cleaned and converted to proper numeric format.
#
# - *Example*  `-79715.0 Shares`

# %%
engagement = ['Views', 'Likes', 'Shares', 'Comments']

negative_mask = train['Views'].astype(str).str.contains('-', na=False)
train[negative_mask][['Post_ID'] + engagement].head(2)
# Out:
#       Post_ID             Views            Likes           Shares  \
# 9   Post_2164   -628363.0 Views   -74367.0 Likes  -94257.0 Shares
# 10  Post_2232  -3371495.0 Views  -283970.0 Likes  -78225.0 Shares
#
#              Comments
# 9   -13383.0 Comments
# 10  -32830.0 Comments

# %%
# Clean engagement metrics - remove text suffixes and convert to numeric
for col in engagement:
    train[col] = train[col].astype(str).str.split().str[0]
    train[col] = pd.to_numeric(train[col], errors='coerce').abs()

print("Engagement columns cleaned and converted to numeric")
train[engagement].head()
# Out:
# Engagement columns cleaned and converted to numeric
#        Views     Likes   Shares  Comments
# 0  3620989.0  185166.0  73884.0   46247.0
# 1  1876306.0  149927.0  65747.0   27923.0
# 2  3494450.0  476260.0  92683.0   40176.0
# 3  2386028.0  156812.0  98830.0   38728.0
# 4  1831366.0  219055.0  32009.0   33612.0

# %% [markdown]
# **Identify Missing Values**

# %%
# Check missing values
print("Missing Values:")
missing_values = train.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Missing Values:
# Views       90
# Likes       90
# Shares      90
# Comments    90
# dtype: int64

# %% [markdown]
# **Filling Missing Engagement Values**

# %%
# Analyze distribution of engagement metrics
from scipy import stats

for col in engagement:
    data = train[col].dropna()
    
    # Calculate skewness
    skewness = stats.skew(data)
    
    # Calculate mean and median
    mean_val = data.mean()
    median_val = data.median()
    
    # Perform normality test
    print(f"\n{col}:")
    print(f"  Mean:     {mean_val:,.2f}")
    print(f"  Median:   {median_val:,.2f}")
    print(f"  Skewness: {skewness:.4f}")
# Out:
# Views:
#   Mean:     2,494,361.60
#   Median:   2,491,489.00
#   Skewness: 0.0034
#
# Likes:
#   Mean:     250,140.34
#   Median:   247,570.00
#   Skewness: -0.0018
#
# Shares:
#   Mean:     50,490.32
#   Median:   50,675.00
#   Skewness: -0.0184
#
# Comments:
#   Mean:     24,905.36
#   Median:   25,029.00
#   Skewness: 0.0068

# %%
# Visualize distributions
from scipy.stats import gaussian_kde

fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

for idx, col in enumerate(engagement):
    data = train[col].dropna()
    
    # Histogram with KDE
    axes[idx].hist(data, bins=50, alpha=0.7, color='skyblue', edgecolor='black', density=True)
    
    kde = gaussian_kde(data)
    x_range = np.linspace(data.min(), data.max(), 100)
    axes[idx].plot(x_range, kde(x_range), 'r-', linewidth=2, label='KDE')
    
    # Mean and median lines
    mean_val, median_val = data.mean(), data.median()
    axes[idx].axvline(mean_val, color='green', linestyle='--', linewidth=2, label=f'Mean: {mean_val:,.0f}')
    axes[idx].axvline(median_val, color='orange', linestyle='--', linewidth=2, label=f'Median: {median_val:,.0f}')
    
    axes[idx].set_title(f'{col} Distribution', fontsize=12, fontweight='bold')
    axes[idx].set_xlabel(col)
    axes[idx].set_ylabel('Density')
    axes[idx].legend()
    axes[idx].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Apply Median Imputation for Data filling**

# %%
# Apply group-specific median imputation
for col in engagement:
    train[col] = train.groupby(['Platform', 'Content_Type'])[col].transform(
        lambda x: x.fillna(x.median())
    )
print("Missing values after imputation:")
print(train[engagement].isnull().sum())
# Out:
# Missing values after imputation:
# Views       0
# Likes       0
# Shares      0
# Comments    0
# dtype: int64

# %% [markdown]
# **Convert Post_Date to DateTime**
#
# Converting the Post_Date column to proper datetime format for time-series analysis.

# %%
train['Post_Date'] = pd.to_datetime(train['Post_Date'], errors='coerce')
print(f"Date range: {train['Post_Date'].min()} to {train['Post_Date'].max()}")
# Out:
# Date range: 2022-01-01 00:00:00 to 2023-12-30 00:00:00

# %% [markdown]
# **Date Extraction**
#
# Extracting additional date-related features from the Post_Date column such as Year, Month, Day, and Day of Week.

# %%
# Extract temporal features from Post_Date
train['Year'] = train['Post_Date'].dt.year
train['Month'] = train['Post_Date'].dt.month
train['Day'] = train['Post_Date'].dt.day
train.drop(columns=['Post_Date'], inplace=True)

# %%
# Reorder columns
train = train[['Post_ID', 'Year', 'Month', 'Day', 
               'Platform', 'Content_Type', 'Hashtag', 'Region', 
               'Views', 'Likes', 'Shares', 'Comments', 'Viral']]
train.head(2)
# Out:
#      Post_ID  Year  Month  Day Platform Content_Type     Hashtag  Region  \
# 0   Post_574  2022     10   10  youtube        video     #gaming  canada
# 1  Post_2708  2023     11    7   tiktok  live stream  #education   india
#
#        Views     Likes   Shares  Comments  Viral
# 0  3620989.0  185166.0  73884.0   46247.0      0
# 1  1876306.0  149927.0  65747.0   27923.0      1

# %% [markdown]
# **Save Cleaned Dataset**

# %%
train.to_csv('DataSet/Hackathon_Train_Cleaned.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 train.to_csv('DataSet/Hackathon_Train_Cleaned.csv', index=False)
#
# File c:\Users\TABLET\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\TABLET\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)   3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\TABLET\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\TABLET\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\TABLET\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\TABLET\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'DataSet'

# %% [markdown]
# **Model Training with XGBoost - Optimized with Feature Selection**

# %%
# Prepare data with advanced feature engineering + Target Encoding
X = train.drop(columns=['Post_ID', 'Viral']).copy()
y = train['Viral']

# Content type features
X['Is_Video'] = (X['Content_Type'] == 'video').astype(int)

# Advanced engagement metrics
X['Engagement_Rate'] = (X['Likes'] + X['Shares'] + X['Comments']) / (X['Views'] + 1)
X['Like_Rate'] = X['Likes'] / (X['Views'] + 1)
X['Share_Rate'] = X['Shares'] / (X['Views'] + 1)
X['Comment_Rate'] = X['Comments'] / (X['Views'] + 1)
X['Virality_Score'] = (X['Shares'] * 3 + X['Comments'] * 2 + X['Likes']) / (X['Views'] + 1)

# Engagement ratios
X['Like_Ratio'] = X['Likes'] / (X['Likes'] + X['Shares'] + X['Comments'] + 1)
X['Share_Ratio'] = X['Shares'] / (X['Likes'] + X['Shares'] + X['Comments'] + 1)

# Log transformations
X['Log_Views'] = np.log1p(X['Views'])
X['Log_Likes'] = np.log1p(X['Likes'])
X['Log_Shares'] = np.log1p(X['Shares'])
X['Log_Comments'] = np.log1p(X['Comments'])

# Interaction features
X['Likes_X_Shares'] = X['Likes'] * X['Shares']

print(f"Features created: {X.shape[1]}")
# Out:
# Features created: 24

# %%
# Split FIRST, then apply target encoding to avoid data leakage
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=seed, stratify=y
)

print(f"Training set size: {X_train.shape[0]}")
print(f"Testing set size: {X_test.shape[0]}")
print(f"\nClass distribution in training set:")
print(y_train.value_counts(normalize=True))
# Out:
# Training set size: 3492
# Testing set size: 873
#
# Class distribution in training set:
# Viral
# 0    0.713631
# 1    0.286369
# Name: proportion, dtype: float64

# %% [markdown]
# **Apply Target Encoding for Categorical Variables**
#
# Target encoding replaces categories with the mean of the target variable for that category, capturing more information than one-hot encoding.

# %%
# Target encode categorical variables using training data only
from imblearn.over_sampling import ADASYN

categorical_cols = ['Platform', 'Content_Type', 'Hashtag', 'Region']

for col in categorical_cols:
    # Calculate mean target per category in training data
    target_means = y_train.groupby(X_train[col]).mean()
    
    # Apply to both train and test
    X_train[col + '_encoded'] = X_train[col].map(target_means)
    X_test[col + '_encoded'] = X_test[col].map(target_means)
    
    # Fill NaN with overall mean (for categories not in training)
    overall_mean = y_train.mean()
    X_train[col + '_encoded'] = X_train[col + '_encoded'].fillna(overall_mean)
    X_test[col + '_encoded'] = X_test[col + '_encoded'].fillna(overall_mean)
    
    # Drop original categorical column
    X_train.drop(columns=[col], inplace=True)
    X_test.drop(columns=[col], inplace=True)

# Apply ADASYN to balance the classes
adasyn = ADASYN(random_state=seed)
X_train_resampled, y_train_resampled = adasyn.fit_resample(X_train, y_train)

print(f"Features after encoding: {X_train.shape[1]}")
print(f"Training samples after ADASYN: {X_train_resampled.shape[0]}")
print(f"Class distribution: {y_train_resampled.value_counts().to_dict()}")
# Out:
# Features after encoding: 24
# Training samples after ADASYN: 4988
# Class distribution: {1: 2496, 0: 2492}

# %%
# Train initial XGBoost to get feature importances
xgb_classifier = xgb.XGBClassifier(
    n_estimators=150,
    max_depth=5,
    learning_rate=0.03,
    min_child_weight=5,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    random_state=seed,
    eval_metric='logloss'
)

xgb_classifier.fit(X_train_resampled, y_train_resampled)

# Get feature importances and select top 10
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': xgb_classifier.feature_importances_
}).sort_values('importance', ascending=False)

print("\nTop 10 most important features:")
print(feature_importance.head(10).to_string(index=False))
# Out:
# Top 10 most important features:
#              feature  importance
#       Virality_Score    0.359075
#      Engagement_Rate    0.145742
#     Platform_encoded    0.075999
# Content_Type_encoded    0.058637
#             Is_Video    0.044822
#      Hashtag_encoded    0.040468
#       Region_encoded    0.022223
#            Like_Rate    0.021533
#                 Year    0.020091
#           Share_Rate    0.018747

# %%
# Train final model with top 10 features
top_features = feature_importance.head(10)['feature'].values
X_train_selected = X_train_resampled[top_features]
X_test_selected = X_test[top_features]

# Final optimized model
model = xgb.XGBClassifier(
    n_estimators=150,
    max_depth=5,
    learning_rate=0.03,
    min_child_weight=5,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=0.1,
    random_state=seed,
    eval_metric='logloss'
)

model.fit(X_train_selected, y_train_resampled)

# Evaluate
y_pred_train = model.predict(X_train[top_features])
y_pred_test = model.predict(X_test_selected)

train_f1 = f1_score(y_train, y_pred_train, average='macro')
test_f1 = f1_score(y_test, y_pred_test, average='macro')

print("\n" + "="*60)
print("FINAL MODEL PERFORMANCE")
print("="*60)
print(f"Training Macro F1 Score: {train_f1:.4f}")
print(f"Testing Macro F1 Score:  {test_f1:.4f}")
print("="*60)
# Out:
# ============================================================
# FINAL MODEL PERFORMANCE
# ============================================================
# Training Macro F1 Score: 0.8187
# Testing Macro F1 Score:  0.8419
# ============================================================
